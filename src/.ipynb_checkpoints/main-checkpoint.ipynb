# %%
import cdsapi

# %%
# Example taken from:
# https://cds-beta.climate.copernicus.eu/how-to-api#use-the-cds-api-client-for-data-access

client = cdsapi.Client()

dataset = 'reanalysis-era5-pressure-levels'
request = {
    'product_type': ['reanalysis'],
    'variable': ['geopotential'],
    'year': ['2024'],
    'month': ['03'],
    'day': ['01'],
    'time': ['13:00'],
    'pressure_level': ['1000'],
    'data_format': 'grib',
}
target = 'download.grib'

client.retrieve(dataset, request, target)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 19
#       7 request = {
#       8     'product_type': ['reanalysis'],
#       9     'variable': ['geopotential'],
#    (...)
#      15     'data_format': 'grib',
#      16 }
#      17 target = 'download.grib'
# ---> 19 client.retrieve(dataset, request, target)
#
# File ~/Software/cassini-hackathon-2024/.venv/lib/python3.12/site-packages/cads_api_client/legacy_api_client.py:153, in LegacyApiClient.retrieve(self, name, request, target)
#     151 submitted: processing.Remote | processing.Results
#     152 if self.wait_until_complete:
# --> 153     submitted = self.logging_decorator(self.client.submit_and_wait_on_result)(
#     154         collection_id=name,
#     155         retry_options=self.retry_options,
#     156         **request,
#     157     )
#     158 else:
#     159     submitted = self.logging_decorator(self.client.submit)(
#     160         collection_id=name,
#     161         retry_options=self.retry_options,
#     162         **request,
#     163     )
#
# File ~/Software/cassini-hackathon-2024/.venv/lib/python3.12/site-packages/cads_api_client/legacy_api_client.py:136, in LegacyApiClient.logging_decorator.<locals>.wrapper(*args, **kwargs)
#     131 @functools.wraps(func)
#     132 def wrapper(*args: Any, **kwargs: Any) -> Any:
#     133     with LoggingContext(
#     134         logger=processing.logger, quiet=self.quiet, debug=self._debug
#     135     ):
# --> 136         return func(*args, **kwargs)
#
# File ~/Software/cassini-hackathon-2024/.venv/lib/python3.12/site-packages/cads_api_client/api_client.py:78, in ApiClient.submit_and_wait_on_result(self, collection_id, retry_options, **request)
#      75 def submit_and_wait_on_result(
#      76     self, collection_id: str, retry_options: dict[str, Any] = {}, **request: Any
#      77 ) -> processing.Results:
# ---> 78     return self.retrieve_api.submit_and_wait_on_result(
#      79         collection_id, retry_options=retry_options, **request
#      80     )
#
# File ~/Software/cassini-hackathon-2024/.venv/lib/python3.12/site-packages/cads_api_client/processing.py:536, in Processing.submit_and_wait_on_result(self, collection_id, retry_options, **request)
#     533 def submit_and_wait_on_result(
#     534     self, collection_id: str, retry_options: dict[str, Any] = {}, **request: Any
#     535 ) -> Results:
# --> 536     remote = self.submit(collection_id, retry_options=retry_options, **request)
#     537     remote.wait_on_result(retry_options=retry_options)
#     538     return remote.make_results()
#
# File ~/Software/cassini-hackathon-2024/.venv/lib/python3.12/site-packages/cads_api_client/processing.py:528, in Processing.submit(self, collection_id, retry_options, **request)
#     525 def submit(
#     526     self, collection_id: str, retry_options: dict[str, Any] = {}, **request: Any
#     527 ) -> Remote:
# --> 528     status_info = self.process_execute(
#     529         collection_id, request, retry_options=retry_options
#     530     )
#     531     return status_info.make_remote(sleep_max=self.sleep_max, cleanup=self.cleanup)
#
# File ~/Software/cassini-hackathon-2024/.venv/lib/python3.12/site-packages/cads_api_client/processing.py:495, in Processing.process_execute(self, process_id, inputs, retry_options, **kwargs)
#     493 url = f"{self.url}/processes/{process_id}/execute"
#     494 headers = kwargs.pop("headers", {})
# --> 495 return StatusInfo.from_request(
#     496     "post",
#     497     url,
#     498     json={"inputs": inputs},
#     499     headers={**self.headers, **headers},
#     500     session=self.session,
#     501     retry_options=retry_options,
#     502     **kwargs,
#     503 )
#
# File ~/Software/cassini-hackathon-2024/.venv/lib/python3.12/site-packages/cads_api_client/processing.py:84, in ApiResponse.from_request(cls, raise_for_status, session, retry_options, *args, **kwargs)
#      81 logger.debug(f"REPLY {response.text}")
#      83 if raise_for_status:
# ---> 84     cads_raise_for_status(response)
#      85 self = cls(response, headers=kwargs.get("headers", {}), session=session)
#      86 self.log_messages()
#
# File ~/Software/cassini-hackathon-2024/.venv/lib/python3.12/site-packages/cads_api_client/processing.py:55, in cads_raise_for_status(response)
#      48     else:
#      49         message = "\n".join(
#      50             [
#      51                 f"{response.status_code} Client Error: {response.reason} for url: {response.url}",
#      52                 error_json_to_message(error_json),
#      53             ]
#      54         )
# ---> 55         raise requests.exceptions.HTTPError(message, response=response)
#      56 response.raise_for_status()
#
# HTTPError: 403 Client Error: Forbidden for url: https://cds-beta.climate.copernicus.eu/api/retrieve/v1/processes/reanalysis-era5-pressure-levels/execute
# required licences not accepted
# required licences not accepted; please accept the following licences to proceed: [{'id': 'licence-to-use-copernicus-products', 'revision': 12}]
